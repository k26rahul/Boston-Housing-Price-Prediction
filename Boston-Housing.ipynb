# %% [markdown]
# # Real Estate Price Prediction

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# housing = pd.read_csv('./housing.data.csv')
housing = pd.read_csv('./data.csv')

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
housing.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       501 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284341
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.705587
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.884000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
len(housing)
housing.shape
housing.columns
# Out:
# 506
# (506, 14)
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
housing['CHAS']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 501    0
# 502    0
# 503    0
# 504    0
# 505    0
# Name: CHAS, Length: 506, dtype: int64

# %%
housing['CHAS'].value_counts()
# Out:
# CHAS
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
housing.iloc[0]
type(housing.iloc[0])
# Out:
# CRIM         0.00632
# ZN          18.00000
# INDUS        2.31000
# CHAS         0.00000
# NOX          0.53800
# RM           6.57500
# AGE         65.20000
# DIS          4.09000
# RAD          1.00000
# TAX        296.00000
# PTRATIO     15.30000
# B          396.90000
# LSTAT        4.98000
# MEDV        24.00000
# Name: 0, dtype: float64
# pandas.core.series.Series

# %%
housing.iloc[0:2]
type(housing.iloc[0:2])
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
#
#        B  LSTAT  MEDV
# 0  396.9   4.98  24.0
# 1  396.9   9.14  21.6
# pandas.core.frame.DataFrame

# %%
housing.iloc[0:2, 0]
type(housing.iloc[0:2, 0])
# Out:
# 0    0.00632
# 1    0.02731
# Name: CRIM, dtype: float64
# pandas.core.series.Series

# %%
housing.iloc[0:2, 0:4]
type(housing.iloc[0:2, 0:4])
# Out:
#       CRIM    ZN  INDUS  CHAS
# 0  0.00632  18.0   2.31     0
# 1  0.02731   0.0   7.07     0
# pandas.core.frame.DataFrame

# %%
housing.loc[[0, 5], ['CRIM', 'INDUS']]
# Out:
#       CRIM  INDUS
# 0  0.00632   2.31
# 5  0.02985   2.18

# %%
housing.hist(bins=50, figsize=(20, 15))
# Out:
# array([[<Axes: title={'center': 'CRIM'}>, <Axes: title={'center': 'ZN'}>,
#         <Axes: title={'center': 'INDUS'}>,
#         <Axes: title={'center': 'CHAS'}>],
#        [<Axes: title={'center': 'NOX'}>, <Axes: title={'center': 'RM'}>,
#         <Axes: title={'center': 'AGE'}>, <Axes: title={'center': 'DIS'}>],
#        [<Axes: title={'center': 'RAD'}>, <Axes: title={'center': 'TAX'}>,
#         <Axes: title={'center': 'PTRATIO'}>,
#         <Axes: title={'center': 'B'}>],
#        [<Axes: title={'center': 'LSTAT'}>,
#         <Axes: title={'center': 'MEDV'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ## Train test split

# %% [markdown]
# ### The manual approach

# %%
np.random.permutation(10)
# Out:
# array([8, 7, 0, 3, 9, 5, 2, 4, 6, 1])

# %%
def split_train_test(data, test_ratio):
    np.random.seed(42)
    shuffled = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train_set, test_set = split_train_test(housing, 0.2)

# %%
train_set
test_set
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS  RAD  TAX  \
# 75    0.09512   0.0  12.83     0  0.4370  6.286  45.0  4.5026    5  398
# 477  15.02340   0.0  18.10     0  0.6140  5.304  97.3  2.1007   24  666
# 15    0.62739   0.0   8.14     0  0.5380  5.834  56.5  4.4986    4  307
# 332   0.03466  35.0   6.06     0  0.4379  6.031  23.3  6.6407    1  304
# 423   7.05042   0.0  18.10     0  0.6140  6.103  85.1  2.0218   24  666
# ..        ...   ...    ...   ...     ...    ...   ...     ...  ...  ...
# 106   0.17120   0.0   8.56     0  0.5200  5.836  91.9  2.2110    5  384
# 270   0.29916  20.0   6.96     0  0.4640  5.856  42.1  4.4290    3  223
# 348   0.01501  80.0   2.01     0  0.4350  6.635  29.7  8.3440    4  280
# 435  11.16040   0.0  18.10     0  0.7400  6.629  94.6  2.1247   24  666
# 102   0.22876   0.0   8.56     0  0.5200  6.405  85.4  2.7147    5  384
#
#      PTRATIO       B  LSTAT  MEDV
# 75      18.7  383.23   8.94  21.4
# ...

# %% [markdown]
# ### Using sklearn `train_test_split`

# %%
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)

# %%
train_set
test_set
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS  RAD  TAX  \
# 477  15.02340   0.0  18.10     0  0.6140  5.304  97.3  2.1007   24  666
# 15    0.62739   0.0   8.14     0  0.5380  5.834  56.5  4.4986    4  307
# 332   0.03466  35.0   6.06     0  0.4379  6.031  23.3  6.6407    1  304
# 423   7.05042   0.0  18.10     0  0.6140  6.103  85.1  2.0218   24  666
# 19    0.72580   0.0   8.14     0  0.5380  5.727  69.5  3.7965    4  307
# ..        ...   ...    ...   ...     ...    ...   ...     ...  ...  ...
# 106   0.17120   0.0   8.56     0  0.5200  5.836  91.9  2.2110    5  384
# 270   0.29916  20.0   6.96     0  0.4640  5.856  42.1  4.4290    3  223
# 348   0.01501  80.0   2.01     0  0.4350  6.635  29.7  8.3440    4  280
# 435  11.16040   0.0  18.10     0  0.7400  6.629  94.6  2.1247   24  666
# 102   0.22876   0.0   8.56     0  0.5200  6.405  85.4  2.7147    5  384
#
#      PTRATIO       B  LSTAT  MEDV
# 477     20.2  349.48  24.91  12.0
# ...

# %% [markdown]
# ### Stratified sampling

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
def do_stratified_sampling(data, attribute):
    split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
    for train_index, test_index in split.split(data, data[attribute]):
        return data.loc[train_index], data.loc[test_index]

# %%
strat_train_set, strat_test_set = do_stratified_sampling(housing, 'CHAS')

# %%
strat_train_set['CHAS'].value_counts()
strat_test_set['CHAS'].value_counts()
# Out:
# CHAS
# 0    376
# 1     28
# Name: count, dtype: int64
# CHAS
# 0    95
# 1     7
# Name: count, dtype: int64

# %%
housing = strat_train_set.copy()

# %% [markdown]
# ## Looking for correlations

# %%
corr_matrix = housing.corr()
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.680857
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %% [markdown]
# ### Correlation scatter plot

# %%
from pandas.plotting import scatter_matrix

# %%
attributes = ['MEDV', 'RM', 'ZN', 'LSTAT']
scatter_matrix(housing[attributes], figsize=(12, 8))
# Out:
# array([[<Axes: xlabel='MEDV', ylabel='MEDV'>,
#         <Axes: xlabel='RM', ylabel='MEDV'>,
#         <Axes: xlabel='ZN', ylabel='MEDV'>,
#         <Axes: xlabel='LSTAT', ylabel='MEDV'>],
#        [<Axes: xlabel='MEDV', ylabel='RM'>,
#         <Axes: xlabel='RM', ylabel='RM'>,
#         <Axes: xlabel='ZN', ylabel='RM'>,
#         <Axes: xlabel='LSTAT', ylabel='RM'>],
#        [<Axes: xlabel='MEDV', ylabel='ZN'>,
#         <Axes: xlabel='RM', ylabel='ZN'>,
#         <Axes: xlabel='ZN', ylabel='ZN'>,
#         <Axes: xlabel='LSTAT', ylabel='ZN'>],
#        [<Axes: xlabel='MEDV', ylabel='LSTAT'>,
#         <Axes: xlabel='RM', ylabel='LSTAT'>,
#         <Axes: xlabel='ZN', ylabel='LSTAT'>,
#         <Axes: xlabel='LSTAT', ylabel='LSTAT'>]], dtype=object)

# %%
housing.plot(kind='scatter', x='RM', y='MEDV', alpha=0.5)
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %% [markdown]
# ## Trying attribute combinations

# %%
housing['TAXRM'] = housing['TAX']/housing['RM']

# %%
housing
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 155  3.53501   0.0  19.58     1  0.871  6.152  82.6  1.7455    5  403
# 423  7.05042   0.0  18.10     0  0.614  6.103  85.1  2.0218   24  666
# 98   0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2  276
# 455  4.75237   0.0  18.10     0  0.713  6.525  86.5  2.4358   24  666
# 216  0.04560   0.0  13.89     1  0.550  5.888  56.0  3.1121    5  276
#
#      PTRATIO       B  LSTAT  MEDV       TAXRM
# 254     16.4  392.89   6.57  21.9   51.571709
# ...

# %%
corr_matrix = housing.corr()
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.680857
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# TAXRM     -0.528626
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %%
housing.plot(kind='scatter', x='TAXRM', y='MEDV', alpha=0.5)
# Out:
# <Axes: xlabel='TAXRM', ylabel='MEDV'>

# %%
housing = strat_train_set.drop(columns=['MEDV'])
housing_labels = strat_train_set['MEDV'].copy()

# %%
housing
housing_labels
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 155  3.53501   0.0  19.58     1  0.871  6.152  82.6  1.7455    5  403
# 423  7.05042   0.0  18.10     0  0.614  6.103  85.1  2.0218   24  666
# 98   0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2  276
# 455  4.75237   0.0  18.10     0  0.713  6.525  86.5  2.4358   24  666
# 216  0.04560   0.0  13.89     1  0.550  5.888  56.0  3.1121    5  276
#
#      PTRATIO       B  LSTAT
# 254     16.4  392.89   6.57
# 348     17.0  390.94   5.99
# 476     20.2  396.21  18.68
# ...

# %% [markdown]
# ## Dealing with missing attributes

# %% [markdown]
# 3 ways to handle missing attributes in a dataset:
#
# 1. **`dropna()`**: Remove rows with missing values.
# 2. **`fillna(value)`**: Replace missing values with a specified value.
# 3. Replace missing values with the mean, median, or mode of the respective column.

# %%
housing_missing = housing.copy()
# housing_missing.loc[0:4, ['RM']] = pd.NA  # Set first five values null
housing_missing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  399.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.279481
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.716784
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.876500
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.209000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630500
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %%
housing_missing['RM']
# Out:
# 254    6.108
# 348    6.635
# 476    6.484
# 321    6.376
# 326    6.312
#        ...
# 155    6.152
# 423    6.103
# 98     7.820
# 455    6.525
# 216    5.888
# Name: RM, Length: 404, dtype: float64

# %%
housing_missing['RM'].describe()
# Out:
# count    399.000000
# mean       6.279481
# std        0.716784
# min        3.561000
# 25%        5.876500
# 50%        6.209000
# 75%        6.630500
# max        8.780000
# Name: RM, dtype: float64

# %%
housing_missing.dropna(subset=['RM']).describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  399.000000  399.000000  399.000000  399.000000  399.000000  399.000000
# mean     3.645234   10.878446   11.377494    0.070175    0.558678    6.279481
# std      8.141128   22.257959    6.873014    0.255763    0.117254    0.716784
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086855    0.000000    5.255000    0.000000    0.453000    5.876500
# 50%      0.289600    0.000000    9.900000    0.000000    0.538000    6.209000
# 75%      3.937625   12.500000   18.100000    0.000000    0.631000    6.630500
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  399.000000  399.000000  399.000000  399.000000  399.000000  399.000000
# mean    68.968421    3.734774    9.796992  413.531328   18.470927  352.880201
# ...

# %%
housing_missing.drop(columns=['RM']).describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX         AGE  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064   69.039851
# std      8.099383   22.150636    6.877817    0.254290    0.116875   28.258248
# min      0.006320    0.000000    0.740000    0.000000    0.389000    2.900000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000   44.850000
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000   78.200000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000   94.100000
# max     73.534100  100.000000   27.740000    1.000000    0.871000  100.000000
#
#               DIS         RAD         TAX     PTRATIO           B       LSTAT
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.746210    9.735149  412.341584   18.473267  353.392822   12.791609
# ...

# %%
housing_missing['RM'].fillna(0)
# Out:
# 254    6.108
# 348    6.635
# 476    6.484
# 321    6.376
# 326    6.312
#        ...
# 155    6.152
# 423    6.103
# 98     7.820
# 455    6.525
# 216    5.888
# Name: RM, Length: 404, dtype: float64

# %%
median = housing_missing['RM'].median()
median
# Out:
# 6.209

# %%
housing_missing['RM'].fillna(median)
# Out:
# 254    6.108
# 348    6.635
# 476    6.484
# 321    6.376
# 326    6.312
#        ...
# 155    6.152
# 423    6.103
# 98     7.820
# 455    6.525
# 216    5.888
# Name: RM, Length: 404, dtype: float64

# %% [markdown]
# ### Imputation - Fill missing data.

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='median')
imputer.fit(housing)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([2.86735e-01, 0.00000e+00, 9.90000e+00, 0.00000e+00, 5.38000e-01,
#        6.20900e+00, 7.82000e+01, 3.12220e+00, 5.00000e+00, 3.37000e+02,
#        1.90000e+01, 3.90955e+02, 1.15700e+01])

# %%
X = imputer.transform(housing_missing)

# %%
housing_tr = pd.DataFrame(X, columns=housing_missing.columns)

# %%
housing_tr.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.278609
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.712366
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.878750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.209000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630000
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %% [markdown]
# ## Creating the pipeline

# %% [markdown]
# **In scikit-learn:**
#
# - Estimators learn from data (e.g., RandomForestClassifier).
# - Transformers preprocess data (e.g., StandardScaler for feature scaling).
# - Predictors make predictions on new data (e.g., using a trained RandomForestClassifier).

# %% [markdown]
# **Feature Scaling:**
# - **Purpose:** Normalize features to a similar scale.
# - **Methods:**
#   - *Min-Max Scaling:* Rescale to [0, 1].
#   - *Standardization:* Mean = 0, SD = 1.
# - **Benefits:**
#   - Avoid dominance of one feature.
#   - Enhance model convergence.

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

data_pipeline = Pipeline([
    ('SimpleImputer', SimpleImputer(strategy='median')),
    ('StandardScaler', StandardScaler()),
])

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  399.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.279481
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.716784
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.876500
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.209000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630500
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %%
housing_num_tr = data_pipeline.fit_transform(housing)

# %%
housing_num_tr.shape
housing_num_tr
# Out:
# (404, 13)
# array([[-0.43942006,  3.12628155, -1.12165014, ..., -0.97491834,
#          0.41164221, -0.86091034],
#        [-0.44352175,  3.12628155, -1.35893781, ..., -0.69277865,
#          0.39131918, -0.94116739],
#        [ 0.15682292, -0.4898311 ,  0.98336806, ...,  0.81196637,
#          0.44624347,  0.81480158],
#        ...,
#        [-0.43525657, -0.4898311 , -1.23083158, ..., -0.22254583,
#          0.41831233, -1.27603303],
#        [ 0.14210728, -0.4898311 ,  0.98336806, ...,  0.81196637,
#         -3.15239177,  0.73869575],
#        [-0.43974024, -0.4898311 ,  0.37049623, ..., -0.97491834,
#          0.41070422,  0.09940681]])

# %% [markdown]
# ## Model selection

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
# model = LinearRegression()
# model = DecisionTreeRegressor()
model = RandomForestRegressor()

# %%
model.fit(housing_num_tr, housing_labels)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ### Model evaluation

# %%
some_data = housing.iloc[:5]
some_labels = housing_labels[:5]
prepared_data = data_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
some_labels
# Out:
# array([22.463, 25.471, 16.331, 23.488, 23.459])
# 254    21.9
# 348    24.5
# 476    16.7
# 321    23.1
# 326    23.0
# Name: MEDV, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score


def rmse(y, y_predicted):
    mse = mean_squared_error(y, y_predicted)
    return mse, np.sqrt(mse)

# %%
housing_predictions = model.predict(housing_num_tr)
rmse(housing_labels, housing_predictions)
# Out:
# (1.3535683217821768, 1.1634295517057218)

# %% [markdown]
# ### Doing cross validation

# %%
scores = cross_val_score(model, housing_num_tr,
                         housing_labels, scoring='neg_mean_squared_error', cv=10)

rmse_scores = np.sqrt(-scores)
rmse_scores.mean()
rmse_scores.std()
rmse_scores
# Out:
# 3.301961620269954
# 0.7040608050208857
# array([2.77806021, 2.72924632, 4.37720047, 2.53091732, 3.3315517 ,
#        2.6303775 , 4.76386489, 3.33641865, 3.34755642, 3.19442273])

# %% [markdown]
# ## Exporting the model

# %%
from joblib import dump, load

# %%
dump(model, 'Boston-Housing-Regressor.joblib')
# Out:
# ['Boston-Housing-Regressor.joblib']

# %% [markdown]
# ## Testing the model on test data

# %%
X_test = strat_test_set.drop(columns=['MEDV'])
y_test = strat_test_set['MEDV'].copy()
X_test_prepared = data_pipeline.transform(X_test)

# %%
y_test_predicted = model.predict(X_test_prepared)
rmse(y_test, y_test_predicted)
# Out:
# (8.486727803921566, 2.913198895359115)

# %%
list(zip(y_test, y_test_predicted))[:5]
# Out:
# [(16.5, 24.637000000000004),
#  (10.2, 11.695999999999987),
#  (30.1, 25.435000000000006),
#  (23.0, 22.012999999999998),
#  (14.4, 18.18799999999999)]

# %% [markdown]
# ## Loading the saved model

# %%
model = load('./Boston-Housing-Regressor.joblib')

# %%
model.predict([
    prepared_data[0]
])
# Out:
# array([22.463])
